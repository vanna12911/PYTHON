# %%
import pandas as pd

# %%
df= pd.read_csv("https://gist.githubusercontent.com/jwalsh/ce1dc0436aba5b7a5c9666f47fa5a380/raw/5ce3854392b43ff97907112d344fc008229b0445/titanic.csv")

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass      Lname  \
# 0            1         0       3     Braund
# 1            2         1       1    Cumings
# 2            3         1       3  Heikkinen
# 3            4         1       1   Futrelle
# 4            5         0       3      Allen
#
#                                           Name     Sex   Age  SibSp  Parch  \
# 0                              Mr. Owen Harris    male  22.0      1      0
# 1   Mrs. John Bradley (Florence Briggs Thayer)  female  38.0      1      0
# 2                                  Miss. Laina  female  26.0      0      0
# 3           Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0
# 4                            Mr. William Henry    male  35.0      0      0
#
#              Ticket     Fare Cabin Embarked
# 0         A/5 21171   7.2500   NaN        S
# 1          PC 17599  71.2833   C85        C
# 2  STON/O2. 3101282   7.9250   NaN        S
# 3            113803  53.1000  C123        S
# ...

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass         Lname                         Name  \
# 151          152         1       1         Pears   Mrs. Thomas (Edith Wearne)
# 152          153         0       3           Meo                  Mr. Alfonzo
# 153          154         0       3  van Billiard            Mr. Austin Blyler
# 154          155         0       3         Olsen               Mr. Ole Martin
# 155          156         0       1      Williams            Mr. Charles Duane
#
#         Sex   Age  SibSp  Parch      Ticket     Fare Cabin Embarked
# 151  female  22.0      1      0      113776  66.6000    C2        S
# 152    male  55.5      0      0  A.5. 11206   8.0500   NaN        S
# 153    male  40.5      0      2    A/5. 851  14.5000   NaN        S
# 154    male   NaN      0      0   Fa 265302   7.3125   NaN        S
# 155    male  51.0      0      1    PC 17597  61.3792   NaN        C

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Lname', 'Name', 'Sex', 'Age',
#        'SibSp', 'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Lname           object
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.shape
# Out:
# (156, 13)

# %%
df.size
# Out:
# 2028

# %%
df.describe()                                                         # describes only numerical data but categorical can also be described if mentioned specifically.
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   156.000000  156.000000  156.000000  126.000000  156.000000
# mean     78.500000    0.346154    2.423077   28.141508    0.615385
# std      45.177428    0.477275    0.795459   14.613880    1.056235
# min       1.000000    0.000000    1.000000    0.830000    0.000000
# 25%      39.750000    0.000000    2.000000   19.000000    0.000000
# 50%      78.500000    0.000000    3.000000   26.000000    0.000000
# 75%     117.250000    1.000000    3.000000   35.000000    1.000000
# max     156.000000    1.000000    3.000000   71.000000    5.000000
#
#             Parch        Fare
# count  156.000000  156.000000
# mean     0.397436   28.109587
# std      0.870146   39.401047
# min      0.000000    6.750000
# 25%      0.000000    8.003150
# 50%      0.000000   14.454200
# 75%      0.000000   30.371850
# max      5.000000  263.000000

# %% [markdown]
# ## Filtering out categorical data

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Lname           object
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.dtypes == object
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Lname           True
# Name            True
# Sex             True
# Age            False
# SibSp          False
# Parch          False
# Ticket          True
# Fare           False
# Cabin           True
# Embarked        True
# dtype: bool

# %%
type(df.dtypes == object)
# Out:
# pandas.core.series.Series

# %%
df.dtypes[df.dtypes==object]
# Out:
# Lname       object
# Name        object
# Sex         object
# Ticket      object
# Cabin       object
# Embarked    object
# dtype: object

# %%
df.dtypes[df.dtypes==object].index
# Out:
# Index(['Lname', 'Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %%
df[df.dtypes[df.dtypes==object].index]
# Out:
#             Lname                                         Name     Sex  \
# 0          Braund                              Mr. Owen Harris    male
# 1         Cumings   Mrs. John Bradley (Florence Briggs Thayer)  female
# 2       Heikkinen                                  Miss. Laina  female
# 3        Futrelle           Mrs. Jacques Heath (Lily May Peel)  female
# 4           Allen                            Mr. William Henry    male
# ..            ...                                          ...     ...
# 151         Pears                   Mrs. Thomas (Edith Wearne)  female
# 152           Meo                                  Mr. Alfonzo    male
# 153  van Billiard                            Mr. Austin Blyler    male
# 154         Olsen                               Mr. Ole Martin    male
# 155      Williams                            Mr. Charles Duane    male
#
#                Ticket Cabin Embarked
# 0           A/5 21171   NaN        S
# 1            PC 17599   C85        C
# ...

# %%
df[df.dtypes[df.dtypes==object].index].describe()
# Out:
#             Lname              Name   Sex Ticket        Cabin Embarked
# count         156               156   156    156           31      155
# unique        141               152     2    145           28        3
# top     Andersson   Miss. Elizabeth  male   2651  C23 C25 C27        S
# freq            4                 2   100      2            2      110

# %% [markdown]
# ## Filtering out intger data

# %%
df.dtypes == int
# Out:
# PassengerId     True
# Survived        True
# Pclass          True
# Lname          False
# Name           False
# Sex            False
# Age            False
# SibSp           True
# Parch           True
# Ticket         False
# Fare           False
# Cabin          False
# Embarked       False
# dtype: bool

# %%
df.dtypes[df.dtypes==int]
# Out:
# PassengerId    int64
# Survived       int64
# Pclass         int64
# SibSp          int64
# Parch          int64
# dtype: object

# %%
df.dtypes[df.dtypes==int ].index
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'SibSp', 'Parch'], dtype='object')

# %%
df[df.dtypes[df.dtypes==int].index]
# Out:
#      PassengerId  Survived  Pclass  SibSp  Parch
# 0              1         0       3      1      0
# 1              2         1       1      1      0
# 2              3         1       3      0      0
# 3              4         1       1      1      0
# 4              5         0       3      0      0
# ..           ...       ...     ...    ...    ...
# 151          152         1       1      1      0
# 152          153         0       3      0      0
# 153          154         0       3      0      2
# 154          155         0       3      0      0
# 155          156         0       1      0      1
#
# [156 rows x 5 columns]

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Lname', 'Name', 'Sex', 'Age',
#        'SibSp', 'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df[['PassengerId', 'Survived']]
# Out:
#      PassengerId  Survived
# 0              1         0
# 1              2         1
# 2              3         1
# 3              4         1
# 4              5         0
# ..           ...       ...
# 151          152         1
# 152          153         0
# 153          154         0
# 154          155         0
# 155          156         0
#
# [156 rows x 2 columns]

# %%
df[['PassengerId', 'Survived']][4:11]
# Out:
#     PassengerId  Survived
# 4             5         0
# 5             6         0
# 6             7         0
# 7             8         0
# 8             9         1
# 9            10         1
# 10           11         1

# %%
df[['PassengerId', 'Survived']][4:11:2]
# Out:
#     PassengerId  Survived
# 4             5         0
# 6             7         0
# 8             9         1
# 10           11         1

# %% [markdown]
# ## adding a new  column into dataframe

# %%
df["new_col"] = 0  # if given existing column name then column data will be overridden

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass      Lname  \
# 0            1         0       3     Braund
# 1            2         1       1    Cumings
# 2            3         1       3  Heikkinen
# 3            4         1       1   Futrelle
# 4            5         0       3      Allen
#
#                                           Name     Sex   Age  SibSp  Parch  \
# 0                              Mr. Owen Harris    male  22.0      1      0
# 1   Mrs. John Bradley (Florence Briggs Thayer)  female  38.0      1      0
# 2                                  Miss. Laina  female  26.0      0      0
# 3           Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0
# 4                            Mr. William Henry    male  35.0      0      0
#
#              Ticket     Fare Cabin Embarked  new_col
# 0         A/5 21171   7.2500   NaN        S        0
# 1          PC 17599  71.2833   C85        C        0
# 2  STON/O2. 3101282   7.9250   NaN        S        0
# ...

# %%
df["summ"] = df['Pclass'] + df['PassengerId']

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass      Lname  \
# 0            1         0       3     Braund
# 1            2         1       1    Cumings
# 2            3         1       3  Heikkinen
# 3            4         1       1   Futrelle
# 4            5         0       3      Allen
#
#                                           Name     Sex   Age  SibSp  Parch  \
# 0                              Mr. Owen Harris    male  22.0      1      0
# 1   Mrs. John Bradley (Florence Briggs Thayer)  female  38.0      1      0
# 2                                  Miss. Laina  female  26.0      0      0
# 3           Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0
# 4                            Mr. William Henry    male  35.0      0      0
#
#              Ticket     Fare Cabin Embarked  new_col  summ
# 0         A/5 21171   7.2500   NaN        S        0     4
# 1          PC 17599  71.2833   C85        C        0     3
# 2  STON/O2. 3101282   7.9250   NaN        S        0     6
# ...

# %%
pd.Categorical(df['Pclass'])
# Out:
# [3, 1, 3, 1, 3, ..., 1, 3, 3, 3, 1]
# Length: 156
# Categories (3, int64): [1, 2, 3]

# %%
pd.Categorical(df["Survived"])
# Out:
# [0, 1, 1, 1, 0, ..., 1, 0, 0, 0, 0]
# Length: 156
# Categories (2, int64): [0, 1]

# %%
df["Survived"].unique()
# Out:
# array([0, 1])

# %%
df["Age"]>18
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 151     True
# 152     True
# 153     True
# 154    False
# 155     True
# Name: Age, Length: 156, dtype: bool

# %%
df[df["Age"]>18]
# Out:
#      PassengerId  Survived  Pclass         Lname  \
# 0              1         0       3        Braund
# 1              2         1       1       Cumings
# 2              3         1       3     Heikkinen
# 3              4         1       1      Futrelle
# 4              5         0       3         Allen
# ..           ...       ...     ...           ...
# 150          151         0       2       Bateman
# 151          152         1       1         Pears
# 152          153         0       3           Meo
# 153          154         0       3  van Billiard
# 155          156         0       1      Williams
#
#                                             Name     Sex   Age  SibSp  Parch  \
# 0                                Mr. Owen Harris    male  22.0      1      0
# 1     Mrs. John Bradley (Florence Briggs Thayer)  female  38.0      1      0
# 2                                    Miss. Laina  female  26.0      0      0
# ...

# %%
len(df) -len(df[df["Age"]>18])
# Out:
# 57

# %%
df[df['Fare']< 28.109587]
# Out:
#      PassengerId  Survived  Pclass         Lname                         Name  \
# 0              1         0       3        Braund              Mr. Owen Harris
# 2              3         1       3     Heikkinen                  Miss. Laina
# 4              5         0       3         Allen            Mr. William Henry
# 5              6         0       3         Moran                    Mr. James
# 7              8         0       3       Palsson        Master. Gosta Leonard
# ..           ...       ...     ...           ...                          ...
# 149          150         0       2         Byles   Rev. Thomas Roussel Davids
# 150          151         0       2       Bateman            Rev. Robert James
# 152          153         0       3           Meo                  Mr. Alfonzo
# 153          154         0       3  van Billiard            Mr. Austin Blyler
# 154          155         0       3         Olsen               Mr. Ole Martin
#
# ...

# %%
len(df) -  len(df[df['Fare']< 28.109587])
# Out:
# 43

# %%
df[df["Fare"] ==0]   # no one gave a fare of zero
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Lname, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked, new_col, summ]
# Index: []

# %%
len(df[df["Fare"] ==0])
# Out:
# 0

# %%
df[df["Sex"]=="male"]
# Out:
#      PassengerId  Survived  Pclass         Lname                    Name  \
# 0              1         0       3        Braund         Mr. Owen Harris
# 4              5         0       3         Allen       Mr. William Henry
# 5              6         0       3         Moran               Mr. James
# 6              7         0       1      McCarthy           Mr. Timothy J
# 7              8         0       3       Palsson   Master. Gosta Leonard
# ..           ...       ...     ...           ...                     ...
# 150          151         0       2       Bateman       Rev. Robert James
# 152          153         0       3           Meo             Mr. Alfonzo
# 153          154         0       3  van Billiard       Mr. Austin Blyler
# 154          155         0       3         Olsen          Mr. Ole Martin
# 155          156         0       1      Williams       Mr. Charles Duane
#
#       Sex   Age  SibSp  Parch       Ticket     Fare Cabin Embarked  new_col  \
# ...

# %%
df[df["Sex"]=="female"]
# Out:
#      PassengerId  Survived  Pclass           Lname  \
# 1              2         1       1         Cumings
# 2              3         1       3       Heikkinen
# 3              4         1       1        Futrelle
# 8              9         1       3         Johnson
# 9             10         1       2          Nasser
# 10            11         1       3       Sandstrom
# 11            12         1       1         Bonnell
# 14            15         0       3         Vestrom
# 15            16         1       2         Hewlett
# 18            19         0       3   Vander Planke
# 19            20         1       3      Masselmani
# 22            23         1       3         McGowan
# 24            25         0       3         Palsson
# 25            26         1       3         Asplund
# 28            29         1       3         O'Dwyer
# 31            32         1       1         Spencer
# 32            33         1       3           Glynn
# ...

# %%
df[df['Pclass']==1]
# Out:
#      PassengerId  Survived  Pclass        Lname  \
# 1              2         1       1      Cumings
# 3              4         1       1     Futrelle
# 6              7         0       1     McCarthy
# 11            12         1       1      Bonnell
# 23            24         1       1       Sloper
# 27            28         0       1      Fortune
# 30            31         0       1    Uruchurtu
# 31            32         1       1      Spencer
# 34            35         0       1        Meyer
# 35            36         0       1    Holverson
# 52            53         1       1       Harper
# 54            55         0       1        Ostby
# 55            56         1       1      Woolner
# 61            62         1       1        Icard
# 62            63         0       1       Harris
# 64            65         0       1      Stewart
# 83            84         0       1       Carrau
# 88            89         1       1      Fortune
# ...

# %%
df[df['Survived'] == 1]
# Out:
#      PassengerId  Survived  Pclass          Lname  \
# 1              2         1       1        Cumings
# 2              3         1       3      Heikkinen
# 3              4         1       1       Futrelle
# 8              9         1       3        Johnson
# 9             10         1       2         Nasser
# 10            11         1       3      Sandstrom
# 11            12         1       1        Bonnell
# 15            16         1       2        Hewlett
# 17            18         1       2       Williams
# 19            20         1       3     Masselmani
# 21            22         1       2        Beesley
# 22            23         1       3        McGowan
# 23            24         1       1         Sloper
# 25            26         1       3        Asplund
# 28            29         1       3        O'Dwyer
# 31            32         1       1        Spencer
# 32            33         1       3          Glynn
# 36            37         1       3          Mamee
# ...

# %%
df[df['Survived'] == 0]
# Out:
#      PassengerId  Survived  Pclass         Lname                    Name  \
# 0              1         0       3        Braund         Mr. Owen Harris
# 4              5         0       3         Allen       Mr. William Henry
# 5              6         0       3         Moran               Mr. James
# 6              7         0       1      McCarthy           Mr. Timothy J
# 7              8         0       3       Palsson   Master. Gosta Leonard
# ..           ...       ...     ...           ...                     ...
# 150          151         0       2       Bateman       Rev. Robert James
# 152          153         0       3           Meo             Mr. Alfonzo
# 153          154         0       3  van Billiard       Mr. Austin Blyler
# 154          155         0       3         Olsen          Mr. Ole Martin
# 155          156         0       1      Williams       Mr. Charles Duane
#
#       Sex   Age  SibSp  Parch       Ticket     Fare Cabin Embarked  new_col  \
# ...

# %%
# females who have paid more than avg fare

df["Sex"]=="female"
df["Fare"]==28.109587

# %%
df[(df["Sex"]=="female") & (df["Fare"]>28.109587)]
# Out:
#      PassengerId  Survived  Pclass      Lname  \
# 1              2         1       1    Cumings
# 3              4         1       1   Futrelle
# 9             10         1       2     Nasser
# 25            26         1       3    Asplund
# 31            32         1       1    Spencer
# 43            44         1       2    Laroche
# 52            53         1       1     Harper
# 61            62         1       1      Icard
# 71            72         0       3    Goodwin
# 88            89         1       1    Fortune
# 119          120         0       3  Andersson
# 147          148         0       3       Ford
# 151          152         1       1      Pears
#
#                                                   Name     Sex   Age  SibSp  \
# 1           Mrs. John Bradley (Florence Briggs Thayer)  female  38.0      1
# 3                   Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 9                          Mrs. Nicholas (Adele Achem)  female  14.0      1
# ...

# %%
max(df['Fare'])
# Out:
# 263.0

# %%
df['Fare']==max(df['Fare'])
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 151    False
# 152    False
# 153    False
# 154    False
# 155    False
# Name: Fare, Length: 156, dtype: bool

# %%
df[df['Fare']==max(df['Fare'])]
# Out:
#     PassengerId  Survived  Pclass    Lname                    Name     Sex  \
# 27           28         0       1  Fortune   Mr. Charles Alexander    male
# 88           89         1       1  Fortune       Miss. Mabel Helen  female
#
#      Age  SibSp  Parch Ticket   Fare        Cabin Embarked  new_col  summ
# 27  19.0      3      2  19950  263.0  C23 C25 C27        S        0    29
# 88  23.0      3      2  19950  263.0  C23 C25 C27        S        0    90

# %%
df[df['Fare']==max(df['Fare'])]['Name']
# Out:
# 27     Mr. Charles Alexander
# 88         Miss. Mabel Helen
# Name: Name, dtype: object

# %%
df[0:100:2]   # row selection way via slicing
# Out:
#     PassengerId  Survived  Pclass          Lname  \
# 0             1         0       3         Braund
# 2             3         1       3      Heikkinen
# 4             5         0       3          Allen
# 6             7         0       1       McCarthy
# 8             9         1       3        Johnson
# 10           11         1       3      Sandstrom
# 12           13         0       3    Saundercock
# 14           15         0       3        Vestrom
# 16           17         0       3           Rice
# 18           19         0       3  Vander Planke
# 20           21         0       2         Fynney
# 22           23         1       3        McGowan
# 24           25         0       3        Palsson
# 26           27         0       3           Emir
# 28           29         1       3        O'Dwyer
# 30           31         0       1      Uruchurtu
# 32           33         1       3          Glynn
# 34           35         0       1          Meyer
# ...

# %%
df.iloc[0:2]
# Out:
#    PassengerId  Survived  Pclass    Lname  \
# 0            1         0       3   Braund
# 1            2         1       1  Cumings
#
#                                           Name     Sex   Age  SibSp  Parch  \
# 0                              Mr. Owen Harris    male  22.0      1      0
# 1   Mrs. John Bradley (Florence Briggs Thayer)  female  38.0      1      0
#
#       Ticket     Fare Cabin Embarked  new_col  summ
# 0  A/5 21171   7.2500   NaN        S        0     4
# 1   PC 17599  71.2833   C85        C        0     3

# %%
df.loc[0:2]
# Out:
#    PassengerId  Survived  Pclass      Lname  \
# 0            1         0       3     Braund
# 1            2         1       1    Cumings
# 2            3         1       3  Heikkinen
#
#                                           Name     Sex   Age  SibSp  Parch  \
# 0                              Mr. Owen Harris    male  22.0      1      0
# 1   Mrs. John Bradley (Florence Briggs Thayer)  female  38.0      1      0
# 2                                  Miss. Laina  female  26.0      0      0
#
#              Ticket     Fare Cabin Embarked  new_col  summ
# 0         A/5 21171   7.2500   NaN        S        0     4
# 1          PC 17599  71.2833   C85        C        0     3
# 2  STON/O2. 3101282   7.9250   NaN        S        0     6

# %%
df.iloc[0:2 , ['PassengerId',	'Survived',	'Pclass']]  # .iloc requires numeric indexers,
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-98-e0acf7618e4b> in <cell line: 1>()
# ----> 1 df.iloc[0:2 , ['PassengerId',   'Survived',     'Pclass']]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1065             if self._is_scalar_access(key):
#    1066                 return self.obj._get_value(*key, takeable=self._takeable)
# -> 1067             return self._getitem_tuple(key)
#    1068         else:
#    1069             # we by definition only have the 0th axis
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1561     def _getitem_tuple(self, tup: tuple):
#    1562
# -> 1563         tup = self._validate_tuple_indexer(tup)
#    1564         with suppress(IndexingError):
#    1565             return self._getitem_lowerdim(tup)
#
# ...

# %%
# df.iloc[0:2][['PassengerId',	'Survived',	'Pclass']]

# %%
df.loc[0:2 ,['PassengerId',	'Survived',	'Pclass']]
# Out:
#    PassengerId  Survived  Pclass
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3

# %%
df.iloc[0:2 , [0,1,2]]
# Out:
#    PassengerId  Survived  Pclass
# 0            1         0       3
# 1            2         1       1

# %% [markdown]
# *  upper bound is silent in .iloc()
# *  upper bound not silent in .loc()
# *  only inbulit indexes are refrenced by .iloc() i.e named indexes are not
#    referenced by  .iloc()
# *  therefore numbered indexes are refernced by .iloc()
# *  but named indexed can be referenced by .loc()
